# %%
# !ls
# Out:
# Data                                    interaction
# Phar_project                            manage.py
# Procfile.dev                            obsolete
# README.md                               protein
# Untitled.ipynb                          requirements.txt
# accounts                                scripts
# blog                                    sitesearch
# build                                   static
# common                                  structure
# db.sqlite3                              temp
# docker                                  templates
# draft_drug                              test-sort-variant-along-protein-seq.csv
# drug                                    unused_apps
# gene                                    variant
# home

# %%
import pandas as pd
pd.set_option('display.max_column', None)

# %%
df = pd.read_csv("test-sort-variant-along-protein-seq.csv")
print(len(df))
df.head(5)
# Out:
# 198
#     vep_id    Transcript_ID Consequence cDNA_position CDS_position  \
# 0   550423  ENST00000000412         syn           189           30
# 1  3244691  ENST00000000412         mis           188           29
# 2  1102552  ENST00000000412         syn           462          303
# 3  4463616  ENST00000000412         mis           463          304
# 4  4504103  ENST00000000412         syn           471          312
#
#   Protein_position Amino_acids   Codons Impact  Strand  \
# 0               10           T  acT/acC      L      -1
# 1               10         T/I  aCt/aTt      M      -1
# 2              101           T  acA/acG      L      -1
# 3              102         V/M  Gtg/Atg      M      -1
# 4              104           G  ggG/ggA      L      -1
#
#    BayesDel_addAF_rankscore  BayesDel_noAF_rankscore  CADD_raw_rankscore  \
# 0                       NaN                      NaN                 NaN
# 1                      0.19                    0.179               0.341
# ...

# %%
df["Protein_position"] = df["Protein_position"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df["Protein_position"] = df["Protein_position"].astype(int)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...
